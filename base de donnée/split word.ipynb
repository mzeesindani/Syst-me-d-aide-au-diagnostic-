# %%
# import pandas as pd
# df_existant = pd.read_excel("nouveau_df.xlsx")



# import pandas as pd
# import numpy as np
# import Levenshtein




# mots_cles = ['sepsis compliqué', 'déshydratation', 'ist',
#              'hépatite B', 'gastro-entérite', 'accouchement avec rétention placentaire',
#             'troubles des règles', 'gale', 'infection urinaire', 'infection des voies respiratoires',
#             'syndrome infectieux', 'avortement incomplet', 'anxiété', 'gastrite', 'fièvre typhoïde', 'retard de croissance', 'angine', 
#             'accès palustre', 'adénopathie inguinale', 'paludisme', "travail d'accouchement", 'aménorrhée',
#             'grippe', 'parasitose intestinale', 'neuropathie périphérique', 'insuffisance veineuse' 'polyarthrite rhumatoïde', 'syndrome coronarien', 'infarctus du myocarde', 'hypertrophie ventriculaire',
#             'hypertension artérielle', 'pneumonie simple', 'hémorragies du premier trimestre de la grossesse', "menace d'avortement", 
#             'tumeur du cerveau', 'hémorroïde externe', 'rhinite', 'stress post-traumatique', 'candidose digestive', 
#             'gastro-entérite', 'mastodynie', 'sepsis', 'teigne tondante', 'toux', 'méningite bactérienne',
#             'hypertension artérielle', 'gastrite chronique', 'corps sans vie', 'IVG', 'coma hépatique', 
#             'syndrome grippal', 'otite', 'bronchopneumonie', 'retard de règles', 'rhinobronchite', 'pharyngite', 
#             'paludisme grave', 'bouchon de cérumen', 'asthme', 'apte à tous travaux', "rupture du tendon d'achille", 
#             'gastroentérite', 'candidose digestive', 'allergie', 'rougeole', 'ulcère gastroduodénal', 'salmonellose', 
#             'gastro-entérite', 'rhinite allergique', 'dermatite atopique', 'infection ORL', 'pharyngite',
#             'pneumonie', 'tuberculose', 'immunodépression', 'neuropathies périphériques', 'ménométrorragie', 'rénine hypocalcémie', 'hypocalcémie', 'amibiase intestinale', 'syndrome infectieux', 
#             'parasitose intestinale', 'reflux gastro-œsophagien', 'anémie', 'cancer du poumon', 'ascaridiose',
#             'État normal', 'rhino-trachéite', 'rhumatisme', 'migraine', 'conjonctivite', 'névralgie', 'hépatomégalie',
#             'syndrome hémolytique urémique', 'gastroentérite non fébrile', 'diabète', 'rachitisme', 'rhumatisme articulaire',
#             'syndrome neuropsychiatrique', 'broncho-pneumonie', 'dysfonction érectile', 'trouble érectile', 
#             'bronchiolite', 'tuberculose pulmonaire', 'apte aux travaux moyens',
#             'syndrome de condensation pulmonaire', 'neuropaludisme', 'rhinite allergique', 'polype nasale',
#             'sciatique', 'tuberculose pulmonaire', 'amibiase intestinale', "syndrome douloureux de l'épigastre", 
#             'gingivite', 'intoxication', 'psychose hallucinatoire', 'insuffisance cardiaque', 'infection urogénitale',
#             'pleurésie', 'coma alcoolique', 'pharyngite', 'rhino-bronchite', 'crise asthmatiforme', 'pyélonéphrite',
#             'dermatite prurigineuse', 'infection uro-digestive', 'syndrome prémenstruel', 'levurose', 'hémorragie post-partum',
#             'amibiase intestinale', 'dermatite prurigineuse', 'varicelle', 'tuberculose osseuse', 'kyste', 'éclampsie',
#             "menace d'accouchement prématuré", 'coma fébrile', 'neuropaludisme', 'méningo-encéphalite', 'cardiopathie',
#             'insuffisance aortique', 'aménorrhée', 'lombosciatite', 'syndrome adhérentiel', 'obésité sévère', 
#             'syndrome hépatite rénal', 'insuffisance rénale', 'asthme intermittent', 'grossesse évolutive',
#             'rafraîchissement thérapeutique', 'grossesse arrêtée', 'algies pelviennes', 'adhérence', 'retard des règles',
#             'aménorrhée', 'bronchite', 'maladie métabolique', 'hypoglycémie', "crise d'asthme", 'syndrome œdémato-ascitique',
#             'adénome', 'adénocarcinome de la prostate', 'rhume', 'Diabète', 'hématopathie', 'splénomégalie tropicale',
#             'ascaridiose', 'avortement', 'gastrite à H. pylori', 'hémorragie', 'coma afebrile', 'syndrome adhérenciel',
#             'otite moyenne chronique', 'rétinopathie hypertensive', 'gynécomastie idiopathique pubertaire',
#             'cystite', 'avortement complet', 'contusion thoracique', 'syndrome douloureux', 'asthme bronchique', 
#             'pleurésie tuberculeuse', 'dermatose', 'syndrome adénoïde', 'entérite fébrile', 'rhinite', 'trachéite',
#             'parasitose intestinale', 'gastrite aiguë', 'choc hypovolémique', 'rétention urinaire', 'névralgie intercostale', 
#             'invagination intestinale', 'méningo-encéphalite', 'hyperuricémie', 'maladie autoimmune', 
#             'parasitose intestinale', 'urétrite', 'myome utérin', 'convulsions fébriles', 'crise asthmatiforme',
#             'ménométrorragie', 'rinites', 'abcès hépatique', 'laryngite', 'gastro-entérite', 'césarienne élective',
#             'Syndrome cave', 'masse médiastinale', 'syndrome myomateux', 'cervicite', 'trouble électrolytique',
#             'maladie amaigrissante', 'névralgie intercostale', 'prolapsus vaginal', 'syndrome cochléaire', 
#             'traumatisme abdominal', 'laryngite', 'fente labiale', 'fièvre éruptive', 'anémie décompensée', 'drépanocytose',
#             'malnutrition', 'covid', 'épilepsie', 'pelvipéritonite', 'staphylococcie cutanée', 
#             'anémie carentielle', 'Rhumatisme articulaire', 'hyperglycémie', 'hypocalcémie', 'lipome épigastrique',
#             'adénocarcinome', 'syndrome rhumatismal', 'drépanocytose', 'rhinopharyngite', 'infections des voies respiratoires supérieures',
#             'hépatite virale B', 'traumatisme crânien', 'rhinite hémorragique', 'rupture utérine', 'cordon ombilical',
#             'abcès', 'malaise', 'césarienne itérative', 'galactorrhée', 'rétinite', 'gastro-entérite',
#             'algoménorrhée', 'hernie inguinale', 'hernie inguinale', 'bronchopneumonie', 'rhino-bronchite', 'rhinopharyngo-amygdalite',
#              'menométrorragie', 'dermatite allergique', 'psoriasis', 'trichomonase intestinale','régime thérapeutique', 
#              'surmenage', 'méningite', 'annexite', 'péritonite', 'staphylococcie cutanée', 'pyélonéphrite',
#              'nécrobiose', 'myomateuse', 'perturbation du cycle', 'toxi-infection', 'salmonellose', 'syndrome de Guillain-Barré',
#              'infection génito-urinaire', 'mycose', 'mastodynie', 'hémicrânie', 'sciatique', 'contusion musculaire thoracique',
#              'intoxication alcoolique', 'allergie', 'rhinotrachéite', 'souffrance fœtale', 'trouble du cycle menstruel',
#              'faux début de travail', 'toux asthmatiforme', 'hépatite virale B', 'dermatite allergique','rétinopathie',
#              'anémie', 'anémie sang', 'choc émotionnel', 
#             ]


# import numpy as np
# mots_cles = np.unique(mots_cles)
# mots_cles




# # Fonction pour trouver les diagnostics les plus similaires dans mots_cles
# def trouver_diagnostics_similaires(diagnostic, mots_cles):
#     mots_diagnostic = diagnostic.split()  # Séparer les mots du diagnostic
#     n = len(mots_diagnostic)
    
#     # Pour stocker les diagnostics similaires
#     diagnostics_similaires = []
#     meilleures_correspondances = set()
#     meilleure_similarite = 0.0
    
#     # Rechercher les combinaisons de mots successifs dans le diagnostic
#     for i in range(n):
#         for j in range(i + 1, min(i + 5, n + 1)):  # Combinaisons de 2 à 4 mots
#             combinaison = ' '.join(mots_diagnostic[i:j])
#             for mot_cle in mots_cles:
#                 sim = 1 - Levenshtein.distance(combinaison, mot_cle) / max(len(combinaison), len(mot_cle))
#                 if sim > meilleure_similarite:
#                     meilleure_similarite = sim
#                     meilleures_correspondances = {mot_cle}
#                 elif sim == meilleure_similarite:
#                     meilleures_correspondances.add(mot_cle)
    
#     # Filtrer les meilleures correspondances pour garder le plus long si un mot est contenu dans un autre
#     for mot1 in meilleures_correspondances:
#         is_contained = False
#         for mot2 in meilleures_correspondances:
#             if mot1 != mot2 and mot1 in mot2:
#                 is_contained = True
#                 break
#         if not is_contained:
#             diagnostics_similaires.append(mot1)
    
#     return diagnostics_similaires

# nouvelles_lignes = []
# # Parcourir chaque ligne du DataFrame original
# for index, row in df_existant.iterrows():
#     diagnostics_similaires = trouver_diagnostics_similaires(row['Diagnostic'], mots_cles)
#     for diag_similaire in diagnostics_similaires:
#         nouvelles_lignes.append({'Service': row['Service'], 'Motif de consultation': row['Motif de consultation'], 'Diagnostic': diag_similaire, 'transcription': row['transcription']})

# # Créer un DataFrame à partir des nouvelles lignes
# df_nouveau = pd.DataFrame(nouvelles_lignes)

# # Afficher le DataFrame résultant
# df_nouveau.head(50)

# %%
import pandas as pd
df_nouveau = pd.read_excel("df_nouveauuu.xlsx")
df_nouveau = df_nouveau.dropna()
df_nouveau.to_csv("df_nouveauuu.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.cm import ScalarMappable

# Supposons que vous avez un DataFrame df avec une colonne 'col' contenant les données
# df = pd.DataFrame({'col': [1, 2, 2, 3, 3, 3, 4, 4, 4, 4]})
# Utilisez votre propre DataFrame ou créez-en un pour les besoins de l'exemple.

# Calcul de la fréquence de répétition des éléments
freq = df_nouveau['Diagnostic'].value_counts()

# Sélection des 50 premiers éléments avec une grande répétition
top_50_high_freq_elements = freq.head(15)

# Création d'une colormap basée sur les fréquences
colors = plt.cm.viridis(top_50_high_freq_elements / top_50_high_freq_elements.max())

# Tracé de l'histogramme avec des couleurs associées aux fréquences
bars = top_50_high_freq_elements.plot(kind='bar', color=colors)

# Configuration du titre et des étiquettes des axes
plt.title('50 premiers éléments avec une grande répétition (Couleur associée au nombre de répétitions)')
plt.xlabel('Éléments')
plt.ylabel('Fréquence')

# Configuration de l'axe y pour n'afficher que les valeurs de fréquence multiples de 2
plt.yticks(np.arange(0, top_50_high_freq_elements.max() + 1, 5))

# Ajout de la légende de couleurs
sm = ScalarMappable(cmap=plt.cm.viridis)
sm.set_array([])


# Affichage du graphique
plt.show()

# %%
freq.head(20)
# Out:
# infection urinaire         567
# paludisme                  486
# grippe                     361
# ist                        318
# gastrite                   303
# travail d'accouchement     264
# hypertension artérielle    208
# syndrome infectieux        199
# fièvre typhoïde            194
# sepsis                     139
# infection urogénitale      127
# parasitose intestinale     100
# malaise                     88
# gastrite chronique          85
# syndrome grippal            78
# grossesse évolutive         72
# État normal                 71
# apte à tous travaux         67
# candidose digestive         61
# grossesse arrêtée           60
# Name: Diagnostic, dtype: int64

# %%
seuil_frequence = 123
df_filtre = df_nouveau[df_nouveau['Diagnostic'].isin(freq[freq >= seuil_frequence ].index)]
# df_filtre_ = df_filtre[df_filtre['Diagnostic'].isin(freq[freq < 99 ].index)]
df_filtre['Diagnostic'].unique()
# Out:
# array(['infection urinaire', 'syndrome infectieux', 'ist',
#        'infection urogénitale', 'gastrite', 'grippe', 'paludisme',
#        "travail d'accouchement", 'sepsis', 'hypertension artérielle',
#        'fièvre typhoïde'], dtype=object)

# %%
df_filtre = df_filtre.reset_index(drop = True)

# %%
df__ = df_filtre.drop(columns=['Unnamed: 0'])
df__.to_csv('df__.csv')

# %%
df__['Diagnostic'].value_counts()
# Out:
# infection urinaire         567
# paludisme                  486
# grippe                     361
# ist                        318
# gastrite                   303
# travail d'accouchement     264
# hypertension artérielle    208
# syndrome infectieux        199
# fièvre typhoïde            194
# sepsis                     139
# infection urogénitale      127
# Name: Diagnostic, dtype: int64

# %%
df__
# Out:
#                  Service Sexe   Etat-civil  Température   FC  FR  \
# 0     pediatrie generale    F  célibataire         36.0  100  24
# 1            gynecologie    F        marié         36.7   88  18
# 2     pediatrie generale    M  célibataire         36.6  100  24
# 3       medecine interne    M        marié         36.0   77  18
# 4       medecine interne    M        marié         36.0   78  20
# ...                  ...  ...          ...          ...  ...  ..
# 3161  pediatrie generale    F  célibataire         36.4  120  28
# 3162  pediatrie generale    M  célibataire         36.9  100  24
# 3163    medecine interne    F  célibataire         36.4   81  17
# 3164         gynecologie    M        marié         36.7   87  18
# 3165  pediatrie generale    M  célibataire         36.6  142  32
#
#       TA Systolique  TA Diastolique  \
# 0               100              60
# 1               121              67
# 2               100              60
# 3               127              86
# 4               117              78
# ...             ...             ...
# 3161            100              60
# 3162            100              60
# 3163            130              88
# 3164            113              77
# 3165            100              60
#
#                                   Motif de consultation             Diagnostic
# 0                              eruption cutanees fievre     infection urinaire
# 1     vomissement nausee polyarthralgie anorexie sur...    syndrome infectieux
# 2                               douleur du genou gauche                    ist
# 3                                  ecoulement urethrale  infection urogénitale
# 4                                                    rt                    ist
# ...                                                 ...                    ...
# 3161  vomissement emission de selles liquides parfoi...                    ist
# 3162                       fievre non chiffree domicile                 sepsis
# 3163                           examen prenuptiaux phase    syndrome infectieux
# 3164                                              check     infection urinaire
# 3165  bombement de la grande fontanelle diminution d...                    ist
#
# [3166 rows x 10 columns]

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder

scalar = StandardScaler()
df_filtre_normalised = scalar.fit_transform(df_filtre[["Température","FC","FR","TA Systolique","TA Diastolique"]])

# encoder = OneHotEncoder()
# df_filtre_OneHot = encoder.fit_transform(df_filtre['Diagnostic'].to_numpy().reshape(-1, 1)).toarray()
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
df_filtre_normalised = pd.DataFrame(df_filtre_normalised)
df_filtre_normalised
# Out:
#              0         1         2         3         4
# 0    -0.043705  0.297006  0.480494 -0.888242 -0.807173
# 1    -0.038284 -0.045843 -0.416730 -0.046897 -0.421136
# 2    -0.039059  0.297006  0.480494 -0.888242 -0.807173
# 3    -0.043705 -0.360122 -0.416730  0.193487  0.626679
# 4    -0.043705 -0.331551 -0.117656 -0.207153  0.185494
# ...        ...       ...       ...       ...       ...
# 3161 -0.040607  0.868421  1.078643 -0.888242 -0.807173
# 3162 -0.036736  0.297006  0.480494 -0.888242 -0.807173
# 3163 -0.040607 -0.245839 -0.566268  0.313679  0.736975
# 3164 -0.038284 -0.074414 -0.416730 -0.367410  0.130345
# 3165 -0.039059  1.496978  1.676793 -0.888242 -0.807173
#
# [3166 rows x 5 columns]

# %%
df_filtre__ = pd.DataFrame(df_filtre['Diagnostic'])
pd.concat([df_filtre_normalised, df_filtre__], axis=1)
# Out:
#              0         1         2         3         4             Diagnostic
# 0    -0.043705  0.297006  0.480494 -0.888242 -0.807173     infection urinaire
# 1    -0.038284 -0.045843 -0.416730 -0.046897 -0.421136    syndrome infectieux
# 2    -0.039059  0.297006  0.480494 -0.888242 -0.807173                    ist
# 3    -0.043705 -0.360122 -0.416730  0.193487  0.626679  infection urogénitale
# 4    -0.043705 -0.331551 -0.117656 -0.207153  0.185494                    ist
# ...        ...       ...       ...       ...       ...                    ...
# 3161 -0.040607  0.868421  1.078643 -0.888242 -0.807173                    ist
# 3162 -0.036736  0.297006  0.480494 -0.888242 -0.807173                 sepsis
# 3163 -0.040607 -0.245839 -0.566268  0.313679  0.736975    syndrome infectieux
# 3164 -0.038284 -0.074414 -0.416730 -0.367410  0.130345     infection urinaire
# 3165 -0.039059  1.496978  1.676793 -0.888242 -0.807173                    ist
#
# [3166 rows x 6 columns]

# %%
df_filtre
# Out:
#       Unnamed: 0             Service Sexe   Etat-civil  Température   FC  FR  \
# 0              4  pediatrie generale    F  célibataire         36.0  100  24
# 1              7         gynecologie    F        marié         36.7   88  18
# 2              8  pediatrie generale    M  célibataire         36.6  100  24
# 3             10    medecine interne    M        marié         36.0   77  18
# 4             11    medecine interne    M        marié         36.0   78  20
# ...          ...                 ...  ...          ...          ...  ...  ..
# 3161        6022  pediatrie generale    F  célibataire         36.4  120  28
# 3162        6023  pediatrie generale    M  célibataire         36.9  100  24
# 3163        6029    medecine interne    F  célibataire         36.4   81  17
# 3164        6032         gynecologie    M        marié         36.7   87  18
# 3165        6033  pediatrie generale    M  célibataire         36.6  142  32
#
#       TA Systolique  TA Diastolique  \
# 0               100              60
# 1               121              67
# 2               100              60
# 3               127              86
# 4               117              78
# ...             ...             ...
# 3161            100              60
# 3162            100              60
# 3163            130              88
# 3164            113              77
# 3165            100              60
#
#                                   Motif de consultation             Diagnostic
# 0                              eruption cutanees fievre     infection urinaire
# 1     vomissement nausee polyarthralgie anorexie sur...    syndrome infectieux
# 2                               douleur du genou gauche                    ist
# 3                                  ecoulement urethrale  infection urogénitale
# 4                                                    rt                    ist
# ...                                                 ...                    ...
# 3161  vomissement emission de selles liquides parfoi...                    ist
# 3162                       fievre non chiffree domicile                 sepsis
# 3163                           examen prenuptiaux phase    syndrome infectieux
# 3164                                              check     infection urinaire
# 3165  bombement de la grande fontanelle diminution d...                    ist
#
# [3166 rows x 11 columns]

# %%
import pandas as pd
import numpy as np

df_nouveau = df_filtre
# Obtenir le décompte des occurrences de chaque état civil
counts = df_nouveau['Diagnostic'].value_counts()

# Définir le nombre maximal d'occurrences à conserver pour les catégories les plus représentées
nombre_occurrences_max = 193

# Créer une liste pour stocker les index des lignes à sélectionner
indexes_a_selectionner = []

# Parcourir chaque catégorie d'état civil
for etat, count_diff in counts.items():
    if count_diff > nombre_occurrences_max:
        # Sélectionner aléatoirement un nombre quelconque d'éléments pour les catégories les plus représentées
        indexes = df_nouveau[df_nouveau['Diagnostic'] == etat].sample(nombre_occurrences_max, random_state=42).index
        indexes_a_selectionner.extend(indexes)
#     else:
#         indexes_a_selectionner.extend(df_nouveau[df_nouveau['Diagnostic'] == etat].index)

# Sélectionner les lignes équilibrées du DataFrame d'origine
df_equilibre = df_nouveau.loc[indexes_a_selectionner]
df_filtre = df_equilibre
# Afficher le DataFrame équilibré

# %%
df_filtre
# Out:
#       Unnamed: 0             Service Sexe   Etat-civil  Température   FC  FR  \
# 3021        5769  pediatrie generale    M  célibataire         36.7  100  28
# 2933        5593  pediatrie generale    F  célibataire         36.6   80  28
# 1309        2508    medecine interne    M        marié         36.0   79  18
# 2965        5656    medecine interne    M        marié         36.0   71  18
# 2747        5201    medecine interne    F        marié         36.1  105  19
# ...          ...                 ...  ...          ...          ...  ...  ..
# 1209        2319    medecine interne    F        marié         36.6   84  18
# 1677        3192  pediatrie generale    F  célibataire         36.7  100  28
# 364          703    medecine interne    M        marié         36.5   74  18
# 1486        2822    medecine interne    M  célibataire         37.0  107  18
# 2987        5689    medecine interne    M        marié         36.0   73  18
#
#       TA Systolique  TA Diastolique  \
# 3021            100              60
# 2933            100              60
# 1309             99              56
# 2965            208             106
# 2747            113              75
# ...             ...             ...
# 1209            134              78
# 1677            100              60
# 364             148              95
# 1486            138              85
# 2987            130              82
#
#                                   Motif de consultation          Diagnostic
# 3021  mictalgie fievre pleurs la miction hematurie t...  infection urinaire
# 2933                               douleurs abdominales  infection urinaire
# 1309                douleur lombaire douleur la miction  infection urinaire
# 2965               chiffre elevee de la ta voix enrouee  infection urinaire
# 2747                   douleur la fosse illiaque droite  infection urinaire
# ...                                                 ...                 ...
# 1209                                           cephalee     fièvre typhoïde
# 1677  douleur auriculaire et limitation de mvmnt de ...     fièvre typhoïde
# 364                 cephalee vertige parfois de frisson     fièvre typhoïde
# 1486                cephalees et vertige polyarthralgie     fièvre typhoïde
# 2987             douleur abdominale et douleur lombaire     fièvre typhoïde
#
# [1737 rows x 11 columns]

# %%
df__ = df_filtre.drop(columns=["Unnamed: 0"]).sample(frac=1, random_state=0).sample(frac=1, random_state=12).reset_index(drop=True)

# %%
df__
# Out:
#                Service Sexe   Etat-civil  Température   FC  FR  TA Systolique  \
# 0     medecine interne    F      veuf ve         36.6   90  18            185
# 1          gynecologie    F        marié         36.6   68  18            126
# 2     medecine interne    M        marié         36.6   92  18            125
# 3     medecine interne    F        marié         36.6   92  26            182
# 4     medecine interne    F  célibataire         36.0   68  18            128
# ...                ...  ...          ...          ...  ...  ..            ...
# 1732  medecine interne    F      veuf ve         36.6   77  18            134
# 1733  medecine interne    M        marié         36.6  116  18            130
# 1734       obstetrique    F        marié         36.5  125  22            117
# 1735  medecine interne    F        marié         36.7   71  18            105
# 1736  medecine interne    M        marié         36.7   73  18            125
#
#       TA Diastolique                              Motif de consultation  \
# 0                 99  douleur cervicale irradiant dans le membre sup...
# 1                 68                       mictalgie douleurs lombaires
# 2                 81                 maux de tete etat general affaibli
# 3                118            ca de transfert pour suspicion d un avc
# 4                 72                                  aptitude physique
# ...              ...                                                ...
# 1732              88  cephalee douleur thoracique douleur abdominale...
# 1733              81     epigastralgie hypogastralgie asthenie physique
# 1734              67                           douleurs lombopelviennes
# 1735              70                                   cephalee et toux
# 1736              85                          rhinorrhee toux cephalees
#
#                    Diagnostic
# 0     hypertension artérielle
# 1         syndrome infectieux
# 2             fièvre typhoïde
# 3     hypertension artérielle
# 4                         ist
# ...                       ...
# 1732                 gastrite
# 1733       infection urinaire
# 1734   travail d'accouchement
# 1735                   grippe
# 1736                   grippe
#
# [1737 rows x 10 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.cm import ScalarMappable


# Calcul de la fréquence de répétition des éléments
freq = df_filtre['Diagnostic'].value_counts()

# Sélection des 50 premiers éléments avec une grande répétition
top_50_high_freq_elements = freq.head(60)

# Création d'une colormap basée sur les fréquences
colors = plt.cm.viridis(top_50_high_freq_elements / top_50_high_freq_elements.max())

# Tracé de l'histogramme avec des couleurs associées aux fréquences
bars = top_50_high_freq_elements.plot(kind='bar', color=colors)

# Configuration du titre et des étiquettes des axes
plt.title('50 premiers éléments avec une grande répétition (Couleur associée au nombre de répétitions)')
plt.xlabel('Éléments')
plt.ylabel('Fréquence')

# Configuration de l'axe y pour n'afficher que les valeurs de fréquence multiples de 2
plt.yticks(np.arange(0, top_50_high_freq_elements.max() + 1, 5))

# Ajout de la légende de couleurs
sm = ScalarMappable(cmap=plt.cm.viridis)
sm.set_array([])


# Affichage du graphique
plt.show()

# %%
df_filtre = df_filtre.drop(columns=["Unnamed: 0"])

# %%
df_filtre
# Out:
#                  Service Sexe   Etat-civil  Température   FC  FR  \
# 3021  pediatrie generale    M  célibataire         36.7  100  28
# 2933  pediatrie generale    F  célibataire         36.6   80  28
# 1309    medecine interne    M        marié         36.0   79  18
# 2965    medecine interne    M        marié         36.0   71  18
# 2747    medecine interne    F        marié         36.1  105  19
# ...                  ...  ...          ...          ...  ...  ..
# 1209    medecine interne    F        marié         36.6   84  18
# 1677  pediatrie generale    F  célibataire         36.7  100  28
# 364     medecine interne    M        marié         36.5   74  18
# 1486    medecine interne    M  célibataire         37.0  107  18
# 2987    medecine interne    M        marié         36.0   73  18
#
#       TA Systolique  TA Diastolique  \
# 3021            100              60
# 2933            100              60
# 1309             99              56
# 2965            208             106
# 2747            113              75
# ...             ...             ...
# 1209            134              78
# 1677            100              60
# 364             148              95
# 1486            138              85
# 2987            130              82
#
#                                   Motif de consultation          Diagnostic
# 3021  mictalgie fievre pleurs la miction hematurie t...  infection urinaire
# 2933                               douleurs abdominales  infection urinaire
# 1309                douleur lombaire douleur la miction  infection urinaire
# 2965               chiffre elevee de la ta voix enrouee  infection urinaire
# 2747                   douleur la fosse illiaque droite  infection urinaire
# ...                                                 ...                 ...
# 1209                                           cephalee     fièvre typhoïde
# 1677  douleur auriculaire et limitation de mvmnt de ...     fièvre typhoïde
# 364                 cephalee vertige parfois de frisson     fièvre typhoïde
# 1486                cephalees et vertige polyarthralgie     fièvre typhoïde
# 2987             douleur abdominale et douleur lombaire     fièvre typhoïde
#
# [1737 rows x 10 columns]

# %%
df_filtre = df_filtre.reset_index(drop=True)

# %%
# seuil_frequence = 38
# df_filtre = df_equilibre[df_equilibre['Diagnostic'].isin(freq[freq >= seuil_frequence ].index)]
# df_filtre_ = df_equilibre[df_equilibre['Diagnostic'].isin(freq[freq < 99 ].index)]
# df_filtre_['Diagnostic'].unique()

# %%
cols= ["Service", "Motif de consultation", "Diagnostic","Sexe","Etat-civil","Température","FC","FR","TA Systolique","TA Diastolique"]


df_filtre.to_csv('./df_filtre.csv')
df_filtre
# Out:
#                  Service Sexe   Etat-civil  Température   FC  FR  \
# 0     pediatrie generale    M  célibataire         36.7  100  28
# 1     pediatrie generale    F  célibataire         36.6   80  28
# 2       medecine interne    M        marié         36.0   79  18
# 3       medecine interne    M        marié         36.0   71  18
# 4       medecine interne    F        marié         36.1  105  19
# ...                  ...  ...          ...          ...  ...  ..
# 1732    medecine interne    F        marié         36.6   84  18
# 1733  pediatrie generale    F  célibataire         36.7  100  28
# 1734    medecine interne    M        marié         36.5   74  18
# 1735    medecine interne    M  célibataire         37.0  107  18
# 1736    medecine interne    M        marié         36.0   73  18
#
#       TA Systolique  TA Diastolique  \
# 0               100              60
# 1               100              60
# 2                99              56
# 3               208             106
# 4               113              75
# ...             ...             ...
# 1732            134              78
# 1733            100              60
# 1734            148              95
# 1735            138              85
# 1736            130              82
#
#                                   Motif de consultation          Diagnostic
# 0     mictalgie fievre pleurs la miction hematurie t...  infection urinaire
# 1                                  douleurs abdominales  infection urinaire
# 2                   douleur lombaire douleur la miction  infection urinaire
# 3                  chiffre elevee de la ta voix enrouee  infection urinaire
# 4                      douleur la fosse illiaque droite  infection urinaire
# ...                                                 ...                 ...
# 1732                                           cephalee     fièvre typhoïde
# 1733  douleur auriculaire et limitation de mvmnt de ...     fièvre typhoïde
# 1734                cephalee vertige parfois de frisson     fièvre typhoïde
# 1735                cephalees et vertige polyarthralgie     fièvre typhoïde
# 1736             douleur abdominale et douleur lombaire     fièvre typhoïde
#
# [1737 rows x 10 columns]

# %%
# Calcul de la fréquence de répétition des éléments
freq = df_filtre['Diagnostic'].value_counts()

# Sélection des 50 premiers éléments avec une grande répétition
top_50_high_freq_elements = freq.head(38)

# Création d'une colormap basée sur les fréquences
colors = plt.cm.viridis(top_50_high_freq_elements / top_50_high_freq_elements.max())

# Tracé de l'histogramme avec des couleurs associées aux fréquences
bars = top_50_high_freq_elements.plot(kind='bar', color=colors)

# Configuration du titre et des étiquettes des axes
plt.title('50 premiers éléments avec une grande répétition (Couleur associée au nombre de répétitions)')
plt.xlabel('Éléments')
plt.ylabel('Fréquence')

# Configuration de l'axe y pour n'afficher que les valeurs de fréquence multiples de 2
plt.yticks(np.arange(0, top_50_high_freq_elements.max() + 1, 5))

# Ajout de la légende de couleurs
sm = ScalarMappable(cmap=plt.cm.viridis)
sm.set_array([])


# Affichage du graphique
plt.show()

# %%
top_50_high_freq_elements
# Out:
# infection urinaire         193
# paludisme                  193
# grippe                     193
# ist                        193
# gastrite                   193
# travail d'accouchement     193
# hypertension artérielle    193
# syndrome infectieux        193
# fièvre typhoïde            193
# Name: Diagnostic, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import warnings
import pickle
import string
import spacy
import nltk 
import re


from sklearn.ensemble import *
from nltk.stem import WordNetLemmatizer 
from spacy.lang.en.stop_words import STOP_WORDS
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, auc, roc_curve
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import learning_curve

# %%
def clean_txt(docs):
    lemmatizer = WordNetLemmatizer() 
    # Correct mispelled words
    #spell = SpellChecker()
    #spellcorrection = [spell.correction(x) for x in docs]
    # split into words
    speech_words = nltk.word_tokenize(docs)
    # convert to lower case
    lower_text = [w.lower() for w in speech_words]
    # prepare regex for char filtering
    re_punc = re.compile('[%s]' % re.escape(string.punctuation))
    # remove punctuation from each word
    stripped = [re_punc.sub('', w) for w in lower_text]
    # remove remaining tokens that are not alphabetic
    words = [word for word in stripped if word.isalpha()]
    # filter out stop words
    words = [w for w in words if not w in  list(STOP_WORDS)]
    #Stemm all the words in the sentence
    lem_words = [lemmatizer.lemmatize(word) for word in words]
    combined_text = ' '.join(lem_words)
    return combined_text

# %%
df_nouveau['Motif de consultation'].unique().size
df_existant = pd.read_csv('./df_filtre.csv')
df_existant
# Out:
#       Unnamed: 0             Service Sexe   Etat-civil  Température   FC  FR  \
# 0              0  pediatrie generale    M  célibataire         36.7  100  28
# 1              1  pediatrie generale    F  célibataire         36.6   80  28
# 2              2    medecine interne    M        marié         36.0   79  18
# 3              3    medecine interne    M        marié         36.0   71  18
# 4              4    medecine interne    F        marié         36.1  105  19
# ...          ...                 ...  ...          ...          ...  ...  ..
# 1732        1732    medecine interne    F        marié         36.6   84  18
# 1733        1733  pediatrie generale    F  célibataire         36.7  100  28
# 1734        1734    medecine interne    M        marié         36.5   74  18
# 1735        1735    medecine interne    M  célibataire         37.0  107  18
# 1736        1736    medecine interne    M        marié         36.0   73  18
#
#       TA Systolique  TA Diastolique  \
# 0               100              60
# 1               100              60
# 2                99              56
# 3               208             106
# 4               113              75
# ...             ...             ...
# 1732            134              78
# 1733            100              60
# 1734            148              95
# 1735            138              85
# 1736            130              82
#
#                                   Motif de consultation          Diagnostic
# 0     mictalgie fievre pleurs la miction hematurie t...  infection urinaire
# 1                                  douleurs abdominales  infection urinaire
# 2                   douleur lombaire douleur la miction  infection urinaire
# 3                  chiffre elevee de la ta voix enrouee  infection urinaire
# 4                      douleur la fosse illiaque droite  infection urinaire
# ...                                                 ...                 ...
# 1732                                           cephalee     fièvre typhoïde
# 1733  douleur auriculaire et limitation de mvmnt de ...     fièvre typhoïde
# 1734                cephalee vertige parfois de frisson     fièvre typhoïde
# 1735                cephalees et vertige polyarthralgie     fièvre typhoïde
# 1736             douleur abdominale et douleur lombaire     fièvre typhoïde
#
# [1737 rows x 11 columns]

# %%
from sklearn.preprocessing import StandardScaler

df = pd.read_csv('df_filtre.csv')
#df = df.sample(frac=1, random_state=42).sample(frac=1, random_state=10).sample(frac=1, random_state=24)
#df_text = df[['Motif de consultation',"Service", 'Diagnostic']]


#df_text['Motif de consultation', "Service"] = df_text['Motif de consultation', "Service"].apply(clean_txt)
colssss = ["Température","FC","FR","TA Systolique","TA Diastolique"]
X = df["Motif de consultation"]
y = df['Diagnostic']
# vec = TfidfVectorizer()

# X = vec.fit_transform(X)
# n=X

prompt = df["Diagnostic"].unique()
prompt_dict = {value:index for index, value in enumerate(prompt)}
results = df["Diagnostic"].map(prompt_dict)
print(f'\n{prompt_dict}\n')

# X__ = pd.DataFrame(X)
# X__[["Température","FC","FR","TA Systolique","TA Diastolique"]]= y = df[["Température","FC","FR","TA Systolique","TA Diastolique"]]
# X = X__.sample(frac=1, random_state=4).sample(frac=1, random_state=43).sample(frac=1, random_state=10)
# X = X.rename(columns = {0: "Motif de consultation"})

# from sklearn.tree import DecisionTreeClassifier

# oversample = RandomOverSampler()
# X_, results_ = oversample.fit_resample(X, results)

# X_train, X_test, y_train, y_test = train_test_split(X, results_, test_size=0.2, random_state=0)
# Out:
# {'infection urinaire': 0, 'paludisme': 1, 'grippe': 2, 'ist': 3, 'gastrite': 4, "travail d'accouchement": 5, 'hypertension artérielle': 6, 'syndrome infectieux': 7, 'fièvre typhoïde': 8}

# %%
df2 = X
df2
# Out:
#                       0
# 0  maman vas au marvher

# %%
import pandas as pd
from nltk import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
import csv
import numpy as np


df2 = X


#dfakim= np.where(len(df['Message'])==0)

for item in range(len(df2)):   
    if item == 0:
        corpus = [df2.loc[item]]
        #print(corpus)
        tok = [word_tokenize(df2.loc[item])]
        wordset = set(tok[item][:])
##print(corpus)
    else:

        corpus.append(df2.loc[item])
        tok.append(word_tokenize(df2.loc[item]))


        wordset = set(tok[0][:]).union(set(tok[item][:]))


tfidf = TfidfVectorizer().fit(corpus)
count = tfidf.get_feature_names_out(corpus)

vector = tfidf.transform(corpus)
df_tfidf_vect = pd.DataFrame(data = vector.toarray(),columns=count)


#df_tfidf_vect.to_csv('tfidf.csv')
#print(df_tfidf_vect[df_tfidf_vect['keystone_authtoken'] > 0])
   

df['Motif de consultation'] =  df_tfidf_vect.sum(axis=1)

df['Motif de consultation']



# pd.set_option('display.max_rows', 10)
# reg = pd.read_csv('C:/Users\hp/Desktop/log/datasetVec3.csv')
# print(reg)
# print(reg.head())
df
# Out:
# 1.414213562373095

# %%
for item in range(len(df2)):   
    dv = df2.loc[item][0]
dv
# Out:
# 'maman vas au marvher'

# %%
import pandas as pd

X = pd.DataFrame(["douleurs abdominales"])

# %%
df = df[["Motif de consultation", "Température","FC","FR","TA Systolique","TA Diastolique", "Diagnostic"]].sample(frac=1, random_state=42).reset_index(drop=True)
#df.to_csv("df_vrai.csv")
df.to_csv("df_vrai.csv")
df
# Out:
#       Motif de consultation  Température   FC  FR  TA Systolique  \
# 0                  3.906947         36.5  154  30            100
# 1                  1.854137         36.6   99  20            120
# 2                  2.609158         36.0  109  18            158
# 3                  2.294421         36.3   78  24            101
# 4                  2.705001         36.5  126  24            121
# ...                     ...          ...  ...  ..            ...
# 3161               3.564879         36.0   55  18            127
# 3162               2.748520         36.1   94  20            188
# 3163               1.400706         37.0  140  28            100
# 3164               1.256073         36.7   92  18            122
# 3165               2.330240         36.5   91  18            130
#
#       TA Diastolique              Diagnostic
# 0                 60                  sepsis
# 1                 80                     ist
# 2                 88      infection urinaire
# 3                 70  travail d'accouchement
# 4                 70  travail d'accouchement
# ...              ...                     ...
# 3161              81                gastrite
# 3162              71                gastrite
# 3163              60                     ist
# 3164              69     syndrome infectieux
# 3165              81   infection urogénitale
#
# [3166 rows x 7 columns]

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder

scalar = StandardScaler()
df_filtre_normalised = scalar.fit_transform(df[["Motif de consultation","Température","FC","FR","TA Systolique","TA Diastolique"]])
df_filtre_normalised = pd.DataFrame(df_filtre_normalised).rename(columns= {0:"Motif de consultation",1:"Température",2:"FC",3:"FR",4:"TA Systolique",5:"TA Diastolique"})
df_filtre__ = pd.DataFrame(df['Diagnostic'])

df_filtre_normaliseddd= pd.concat([df_filtre_normalised, df_filtre__], axis=1)

# %%
df_filtre_normaliseddd.to_csv("df_vrai.csv")

# %%
df_filtre_normaliseddd
# Out:
#       Motif de consultation  Température        FC        FR  TA Systolique  \
# 0                  0.276247    -0.373744 -0.045843 -0.416730      -1.008434
# 1                 -0.523000    -0.040900 -0.531546 -0.416730       0.754383
# 2                 -1.095556     0.158806 -0.245839 -0.117656      -0.687922
# 3                 -0.287059    -0.373744 -0.302980 -0.117656      -0.487602
# 4                  1.002665    -0.373744  0.068440 -0.416730       1.595727
# ...                     ...          ...       ...       ...            ...
# 3161               1.488521     0.092238 -0.502975 -0.416730      -0.006833
# 3162              -0.571546    -0.373744 -0.502975 -0.117656      -0.086961
# 3163               2.163156     0.025669  0.639855  0.480494      -0.487602
# 3164              -1.045818     2.155872  0.925563  0.779569      -0.888242
# 3165              -1.032326    -0.174038  1.439836  3.172167      -0.888242
#
#       TA Diastolique              Diagnostic
# 0          -0.917469                  grippe
# 1           0.185494      infection urinaire
# 2          -0.476284  travail d'accouchement
# 3           0.240642               paludisme
# 4           1.123012                  grippe
# ...              ...                     ...
# 3161       -0.200543                gastrite
# 3162       -0.807173                gastrite
# 3163       -0.807173   infection urogénitale
# 3164        0.461234      infection urinaire
# 3165       -0.807173                  sepsis
#
# [3166 rows x 7 columns]

# %%
# import pandas as pd
# import numpy as np
# import Levenshtein


# mots_cles = ['sepsis compliqué', 'déshydratation', 'ist',
#              'hépatite B', 'gastro-entérite', 'accouchement avec rétention placentaire',
#             'troubles des règles', 'gale', 'infection urinaire', 'infection des voies respiratoires',
#             'syndrome infectieux', 'avortement incomplet', 'anxiété', 'gastrite', 'fièvre typhoïde', 'retard de croissance', 'angine', 
#             'accès palustre', 'adénopathie inguinale', 'paludisme', "travail d'accouchement", 'aménorrhée',
#             'grippe', 'parasitose intestinale', 'neuropathie périphérique', 'insuffisance veineuse' 'polyarthrite rhumatoïde', 'syndrome coronarien', 'infarctus du myocarde', 'hypertrophie ventriculaire',
#             'hypertension artérielle', 'pneumonie simple', 'hémorragies du premier trimestre de la grossesse', "menace d'avortement", 
#             'tumeur du cerveau', 'hémorroïde externe', 'rhinite', 'stress post-traumatique', 'candidose digestive', 
#             'gastro-entérite', 'mastodynie', 'sepsis', 'teigne tondante', 'toux', 'méningite bactérienne',
#             'hypertension artérielle', 'gastrite chronique', 'corps sans vie', 'IVG', 'coma hépatique', 
#             'syndrome grippal', 'otite', 'bronchopneumonie', 'retard de règles', 'rhinobronchite', 'pharyngite', 
#             'paludisme grave', 'bouchon de cérumen', 'asthme', 'apte à tous travaux', "rupture du tendon d'achille", 
#             'gastroentérite', 'candidose digestive', 'allergie', 'rougeole', 'ulcère gastroduodénal', 'salmonellose', 
#             'gastro-entérite', 'rhinite allergique', 'dermatite atopique', 'infection ORL', 'pharyngite',
#             'pneumonie', 'tuberculose', 'immunodépression', 'neuropathies périphériques', 'ménométrorragie', 'rénine hypocalcémie', 'hypocalcémie', 'amibiase intestinale', 'syndrome infectieux', 
#             'parasitose intestinale', 'reflux gastro-œsophagien', 'anémie', 'cancer du poumon', 'ascaridiose',
#             'État normal', 'rhino-trachéite', 'rhumatisme', 'migraine', 'conjonctivite', 'névralgie', 'hépatomégalie',
#             'syndrome hémolytique urémique', 'gastroentérite non fébrile', 'diabète', 'rachitisme', 'rhumatisme articulaire',
#             'syndrome neuropsychiatrique', 'broncho-pneumonie', 'dysfonction érectile', 'trouble érectile', 
#             'bronchiolite', 'tuberculose pulmonaire', 'apte aux travaux moyens',
#             'syndrome de condensation pulmonaire', 'neuropaludisme', 'rhinite allergique', 'polype nasale',
#             'sciatique', 'tuberculose pulmonaire', 'amibiase intestinale', "syndrome douloureux de l'épigastre", 
#             'gingivite', 'intoxication', 'psychose hallucinatoire', 'insuffisance cardiaque', 'infection urogénitale',
#             'pleurésie', 'coma alcoolique', 'pharyngite', 'rhino-bronchite', 'crise asthmatiforme', 'pyélonéphrite',
#             'dermatite prurigineuse', 'infection uro-digestive', 'syndrome prémenstruel', 'levurose', 'hémorragie post-partum',
#             'amibiase intestinale', 'dermatite prurigineuse', 'varicelle', 'tuberculose osseuse', 'kyste', 'éclampsie',
#             "menace d'accouchement prématuré", 'coma fébrile', 'neuropaludisme', 'méningo-encéphalite', 'cardiopathie',
#             'insuffisance aortique', 'aménorrhée', 'lombosciatite', 'syndrome adhérentiel', 'obésité sévère', 
#             'syndrome hépatite rénal', 'insuffisance rénale', 'asthme intermittent', 'grossesse évolutive',
#             'rafraîchissement thérapeutique', 'grossesse arrêtée', 'algies pelviennes', 'adhérence', 'retard des règles',
#             'aménorrhée', 'bronchite', 'maladie métabolique', 'hypoglycémie', "crise d'asthme", 'syndrome œdémato-ascitique',
#             'adénome', 'adénocarcinome de la prostate', 'rhume', 'Diabète', 'hématopathie', 'splénomégalie tropicale',
#             'ascaridiose', 'avortement', 'gastrite à H. pylori', 'hémorragie', 'coma afebrile', 'syndrome adhérenciel',
#             'otite moyenne chronique', 'rétinopathie hypertensive', 'gynécomastie idiopathique pubertaire',
#             'cystite', 'avortement complet', 'contusion thoracique', 'syndrome douloureux', 'asthme bronchique', 
#             'pleurésie tuberculeuse', 'dermatose', 'syndrome adénoïde', 'entérite fébrile', 'rhinite', 'trachéite',
#             'parasitose intestinale', 'gastrite aiguë', 'choc hypovolémique', 'rétention urinaire', 'névralgie intercostale', 
#             'invagination intestinale', 'méningo-encéphalite', 'hyperuricémie', 'maladie autoimmune', 
#             'parasitose intestinale', 'urétrite', 'myome utérin', 'convulsions fébriles', 'crise asthmatiforme',
#             'ménométrorragie', 'rinites', 'abcès hépatique', 'laryngite', 'gastro-entérite', 'césarienne élective',
#             'Syndrome cave', 'masse médiastinale', 'syndrome myomateux', 'cervicite', 'trouble électrolytique',
#             'maladie amaigrissante', 'névralgie intercostale', 'prolapsus vaginal', 'syndrome cochléaire', 
#             'traumatisme abdominal', 'laryngite', 'fente labiale', 'fièvre éruptive', 'anémie décompensée', 'drépanocytose',
#             'malnutrition', 'covid', 'épilepsie', 'pelvipéritonite', 'staphylococcie cutanée', 
#             'anémie carentielle', 'Rhumatisme articulaire', 'hyperglycémie', 'hypocalcémie', 'lipome épigastrique',
#             'adénocarcinome', 'syndrome rhumatismal', 'drépanocytose', 'rhinopharyngite', 'infections des voies respiratoires supérieures',
#             'hépatite virale B', 'traumatisme crânien', 'rhinite hémorragique', 'rupture utérine', 'cordon ombilical',
#             'abcès', 'malaise', 'césarienne itérative', 'galactorrhée', 'rétinite', 'gastro-entérite',
#             'algoménorrhée', 'hernie inguinale', 'hernie inguinale', 'bronchopneumonie', 'rhino-bronchite', 'rhinopharyngo-amygdalite',
#              'menométrorragie', 'dermatite allergique', 'psoriasis', 'trichomonase intestinale','régime thérapeutique', 
#              'surmenage', 'méningite', 'annexite', 'péritonite', 'staphylococcie cutanée', 'pyélonéphrite',
#              'nécrobiose', 'myomateuse', 'perturbation du cycle', 'toxi-infection', 'salmonellose', 'syndrome de Guillain-Barré',
#              'infection génito-urinaire', 'mycose', 'mastodynie', 'hémicrânie', 'sciatique', 'contusion musculaire thoracique',
#              'intoxication alcoolique', 'allergie', 'rhinotrachéite', 'souffrance fœtale', 'trouble du cycle menstruel',
#              'faux début de travail', 'toux asthmatiforme', 'hépatite virale B', 'dermatite allergique','rétinopathie',
#              'anémie', 'anémie sang', 'choc émotionnel', 
#             ]


# import numpy as np
# mots_cles = np.unique(mots_cles)
# mots_cles

# # Fonction pour trouver le diagnostic le plus similaire dans mots_cles
# def trouver_diagnostic_similaire(diagnostic, mots_cles):
#     mots_diagnostic = diagnostic.split()  # Séparer les mots du diagnostic
#     n = len(mots_diagnostic)
    
#     # Pour stocker les meilleures correspondances
#     meilleures_correspondances = []
#     meilleure_similarite = 0.0
    
#     # Rechercher les combinaisons de mots successifs dans le diagnostic
#     for i in range(n):
#         for j in range(i + 1, min(i + 5, n + 1)):  # Combinaisons de 2 à 4 mots
#             combinaison = ' '.join(mots_diagnostic[i:j])
#             for mot_cle in mots_cles:
#                 sim = 1 - Levenshtein.distance(combinaison, mot_cle) / max(len(combinaison), len(mot_cle))
#                 if sim > meilleure_similarite:
#                     meilleure_similarite = sim
#                     meilleures_correspondances = [mot_cle]
#                 elif sim == meilleure_similarite:
#                     meilleures_correspondances.append(mot_cle)
    
#     # Retourner une chaîne unique avec les meilleures correspondances
#     return ', '.join(meilleures_correspondances)


# # Fonction pour remplacer les diagnostics par ceux qui correspondent le mieux dans mots_cles
# def remplacer_diagnostics(df, mots_cles):
#     df_replace = df.copy()
#     df_replace['Diagnostic'] = df['Diagnostic'].apply(lambda x: trouver_diagnostic_similaire(x, mots_cles))
#     return df_replace

# # Appeler la fonction pour remplacer les diagnostics
# df_remplace = remplacer_diagnostics(df_existant, mots_cles)

# # Afficher le DataFrame résultant
# df_remplace.head(50)

# %%
# import pandas as pd
# import numpy as np
# import Levenshtein


# mots_cles = ['sepsis compliqué', 'déshydratation', 'ist',
#              'hépatite B', 'gastro-entérite', 'accouchement avec rétention placentaire',
#             'troubles des règles', 'gale', 'infection urinaire', 'infection des voies respiratoires',
#             'syndrome infectieux', 'avortement incomplet', 'anxiété', 'gastrite', 'fièvre typhoïde', 'retard de croissance', 'angine', 
#             'accès palustre', 'adénopathie inguinale', 'paludisme', "travail d'accouchement", 'aménorrhée',
#             'grippe', 'parasitose intestinale', 'neuropathie périphérique', 'insuffisance veineuse' 'polyarthrite rhumatoïde', 'syndrome coronarien', 'infarctus du myocarde', 'hypertrophie ventriculaire',
#             'hypertension artérielle', 'pneumonie simple', 'hémorragies du premier trimestre de la grossesse', "menace d'avortement", 
#             'tumeur du cerveau', 'hémorroïde externe', 'rhinite', 'stress post-traumatique', 'candidose digestive', 
#             'gastro-entérite', 'mastodynie', 'sepsis', 'teigne tondante', 'toux', 'méningite bactérienne',
#             'hypertension artérielle', 'gastrite chronique', 'corps sans vie', 'IVG', 'coma hépatique', 
#             'syndrome grippal', 'otite', 'bronchopneumonie', 'retard de règles', 'rhinobronchite', 'pharyngite', 
#             'paludisme grave', 'bouchon de cérumen', 'asthme', 'apte à tous travaux', "rupture du tendon d'achille", 
#             'gastroentérite', 'candidose digestive', 'allergie', 'rougeole', 'ulcère gastroduodénal', 'salmonellose', 
#             'gastro-entérite', 'rhinite allergique', 'dermatite atopique', 'infection ORL', 'pharyngite',
#             'pneumonie', 'tuberculose', 'immunodépression', 'neuropathies périphériques', 'ménométrorragie', 'rénine hypocalcémie', 'hypocalcémie', 'amibiase intestinale', 'syndrome infectieux', 
#             'parasitose intestinale', 'reflux gastro-œsophagien', 'anémie', 'cancer du poumon', 'ascaridiose',
#             'État normal', 'rhino-trachéite', 'rhumatisme', 'migraine', 'conjonctivite', 'névralgie', 'hépatomégalie',
#             'syndrome hémolytique urémique', 'gastroentérite non fébrile', 'diabète', 'rachitisme', 'rhumatisme articulaire',
#             'syndrome neuropsychiatrique', 'broncho-pneumonie', 'dysfonction érectile', 'trouble érectile', 
#             'bronchiolite', 'tuberculose pulmonaire', 'apte aux travaux moyens',
#             'syndrome de condensation pulmonaire', 'neuropaludisme', 'rhinite allergique', 'polype nasale',
#             'sciatique', 'tuberculose pulmonaire', 'amibiase intestinale', "syndrome douloureux de l'épigastre", 
#             'gingivite', 'intoxication', 'psychose hallucinatoire', 'insuffisance cardiaque', 'infection urogénitale',
#             'pleurésie', 'coma alcoolique', 'pharyngite', 'rhino-bronchite', 'crise asthmatiforme', 'pyélonéphrite',
#             'dermatite prurigineuse', 'infection uro-digestive', 'syndrome prémenstruel', 'levurose', 'hémorragie post-partum',
#             'amibiase intestinale', 'dermatite prurigineuse', 'varicelle', 'tuberculose osseuse', 'kyste', 'éclampsie',
#             "menace d'accouchement prématuré", 'coma fébrile', 'neuropaludisme', 'méningo-encéphalite', 'cardiopathie',
#             'insuffisance aortique', 'aménorrhée', 'lombosciatite', 'syndrome adhérentiel', 'obésité sévère', 
#             'syndrome hépatite rénal', 'insuffisance rénale', 'asthme intermittent', 'grossesse évolutive',
#             'rafraîchissement thérapeutique', 'grossesse arrêtée', 'algies pelviennes', 'adhérence', 'retard des règles',
#             'aménorrhée', 'bronchite', 'maladie métabolique', 'hypoglycémie', "crise d'asthme", 'syndrome œdémato-ascitique',
#             'adénome', 'adénocarcinome de la prostate', 'rhume', 'Diabète', 'hématopathie', 'splénomégalie tropicale',
#             'ascaridiose', 'avortement', 'gastrite à H. pylori', 'hémorragie', 'coma afebrile', 'syndrome adhérenciel',
#             'otite moyenne chronique', 'rétinopathie hypertensive', 'gynécomastie idiopathique pubertaire',
#             'cystite', 'avortement complet', 'contusion thoracique', 'syndrome douloureux', 'asthme bronchique', 
#             'pleurésie tuberculeuse', 'dermatose', 'syndrome adénoïde', 'entérite fébrile', 'rhinite', 'trachéite',
#             'parasitose intestinale', 'gastrite aiguë', 'choc hypovolémique', 'rétention urinaire', 'névralgie intercostale', 
#             'invagination intestinale', 'méningo-encéphalite', 'hyperuricémie', 'maladie autoimmune', 
#             'parasitose intestinale', 'urétrite', 'myome utérin', 'convulsions fébriles', 'crise asthmatiforme',
#             'ménométrorragie', 'rinites', 'abcès hépatique', 'laryngite', 'gastro-entérite', 'césarienne élective',
#             'Syndrome cave', 'masse médiastinale', 'syndrome myomateux', 'cervicite', 'trouble électrolytique',
#             'maladie amaigrissante', 'névralgie intercostale', 'prolapsus vaginal', 'syndrome cochléaire', 
#             'traumatisme abdominal', 'laryngite', 'fente labiale', 'fièvre éruptive', 'anémie décompensée', 'drépanocytose',
#             'malnutrition', 'covid', 'épilepsie', 'pelvipéritonite', 'staphylococcie cutanée', 
#             'anémie carentielle', 'Rhumatisme articulaire', 'hyperglycémie', 'hypocalcémie', 'lipome épigastrique',
#             'adénocarcinome', 'syndrome rhumatismal', 'drépanocytose', 'rhinopharyngite', 'infections des voies respiratoires supérieures',
#             'hépatite virale B', 'traumatisme crânien', 'rhinite hémorragique', 'rupture utérine', 'cordon ombilical',
#             'abcès', 'malaise', 'césarienne itérative', 'galactorrhée', 'rétinite', 'gastro-entérite',
#             'algoménorrhée', 'hernie inguinale', 'hernie inguinale', 'bronchopneumonie', 'rhino-bronchite', 'rhinopharyngo-amygdalite',
#              'menométrorragie', 'dermatite allergique', 'psoriasis', 'trichomonase intestinale','régime thérapeutique', 
#              'surmenage', 'méningite', 'annexite', 'péritonite', 'staphylococcie cutanée', 'pyélonéphrite',
#              'nécrobiose', 'myomateuse', 'perturbation du cycle', 'toxi-infection', 'salmonellose', 'syndrome de Guillain-Barré',
#              'infection génito-urinaire', 'mycose', 'mastodynie', 'hémicrânie', 'sciatique', 'contusion musculaire thoracique',
#              'intoxication alcoolique', 'allergie', 'rhinotrachéite', 'souffrance fœtale', 'trouble du cycle menstruel',
#              'faux début de travail', 'toux asthmatiforme', 'hépatite virale B', 'dermatite allergique','rétinopathie',
#              'anémie', 'anémie sang', 'choc émotionnel', 
#             ]


# import numpy as np
# mots_cles = np.unique(mots_cles)
# mots_cles



# # Fonction pour trouver le diagnostic le plus similaire dans mots_cles
# def trouver_diagnostic_similaire(diagnostic, mots_cles):
#     mots_diagnostic = diagnostic.split()  # Séparer les mots du diagnostic
#     n = len(mots_diagnostic)
    
#     # Pour stocker les meilleures correspondances
#     meilleures_correspondances = []
#     meilleure_similarite = 0.0
    
#     # Rechercher les combinaisons de mots successifs dans le diagnostic
#     for i in range(n):
#         for j in range(i + 1, min(i + 5, n + 1)):  # Combinaisons de 2 à 4 mots
#             combinaison = ' '.join(mots_diagnostic[i:j])
#             for mot_cle in mots_cles:
#                 sim = 1 - Levenshtein.distance(combinaison, mot_cle) / max(len(combinaison), len(mot_cle))
#                 if sim > meilleure_similarite:
#                     meilleure_similarite = sim
#                     meilleures_correspondances = [mot_cle]
#                 elif sim == meilleure_similarite:
#                     meilleures_correspondances.append(mot_cle)
    
#     # Filtrer les meilleures correspondances pour garder le plus long si un mot est contenu dans un autre
#     meilleures_correspondances_filtrees = []
#     for mot1 in meilleures_correspondances:
#         is_contained = False
#         for mot2 in meilleures_correspondances:
#             if mot1 != mot2 and mot1 in mot2:
#                 is_contained = True
#                 break
#         if not is_contained:
#             meilleures_correspondances_filtrees.append(mot1)
    
#     # Retourner une chaîne unique avec les meilleures correspondances filtrées
#     return ', '.join(meilleures_correspondances_filtrees)

# # Fonction pour remplacer les diagnostics par ceux qui correspondent le mieux dans mots_cles
# def remplacer_diagnostics(df, mots_cles):
#     df_replace = df.copy()
#     df_replace['Diagnostic'] = df['Diagnostic'].apply(lambda x: trouver_diagnostic_similaire(x, mots_cles))
#     return df_replace

# # Appeler la fonction pour remplacer les diagnostics
# df_remplace = remplacer_diagnostics(df_existant, mots_cles)

# # Afficher le DataFrame résultant
# df_remplace.head(50)

# %%
# importation des package
import pandas as pd


data_base= pd.read_excel("./Fiche de consultation reserach_ML.xlsx",  skiprows=0)

# %%
data_base
